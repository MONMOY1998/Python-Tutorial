# %%
from math import *

import matplotlib.pyplot as plt

def f(x,y):
    return (1.3*exp(-x)-2*y)

x=float(input("Enter value of x="))
y=float(input("Enter value of y="))
h=float(input("Enter value of h="))
n=int(input("Enter value of n="))

X=[]
Y=[]


for i in range(1,n):
    k1=h*f(x,y)
    k2=h*f(x+h,y+k1)
    x=x+h
    y=y+0.5*(k1+k2)
    
    X.append(x)
    Y.append(y)
    
    print("The value of i is:",i)
    print("The value of x is",x)
    print("The value of y at",x,"is",y)
    
    
plt.plot(X,Y)

plt.scatter(X,Y)

plt.show()
# Out:
# Enter value of x=0
# Enter value of y=5
# Enter value of h=0.05
# Enter value of n=100
# The value of i is: 1
# The value of x is 0.05
# The value of y at 0.05 is 4.585164956296273
# The value of i is: 2
# The value of x is 0.1
# The value of y at 0.1 is 4.206804962200942
# The value of i is: 3
# The value of x is 0.15000000000000002
# The value of y at 0.15000000000000002 is 3.8615979945032186
# The value of i is: 4
# The value of x is 0.2
# The value of y at 0.2 is 3.5465306428108803
# The value of i is: 5
# The value of x is 0.25
# The value of y at 0.25 is 3.258869131721198
# The value of i is: 6
# The value of x is 0.3
# The value of y at 0.3 is 2.9961330792846788
# The value of i is: 7
# The value of x is 0.35
# The value of y at 0.35 is 2.7560717326234325
# The value of i is: 8
# The value of x is 0.39999999999999997
# The value of y at 0.39999999999999997 is 2.5366424461446373
# The value of i is: 9
# The value of x is 0.44999999999999996
# ...

# %%
from math import exp

f=lambda x,y:x*y
#z =lambda x:exp((x**2)/2)

x=0
xn=2
y=1
h=0.2
n=int((xn-x)/h)

print("x \t\t y(RK2) \t K1   \t\t K2   \t\t y(Analytical)")
print("%f \t %f \t %f \t %f \t %f" % (x,y,K1,K2,z(x)))
    

for i in range(1,n+1):
    K1=h*f(x,y)
    K2=h*f(x+h,y+K1)
    y+=(1/2)*(K1+K2)
    x+=h
    print("%f \t %f \t %f \t %f \t %f" % (x,y,K1,K2,z(x)))
# Out:
# x 		 y(RK2) 	 K1   		 K2   		 y(Analytical)
# 0.000000 	 1.000000 	 1.790961 	 2.706341 	 1.000000
# 0.200000 	 1.020000 	 0.000000 	 0.040000 	 1.020201
# 0.400000 	 1.082832 	 0.040800 	 0.084864 	 1.083287
# 0.600000 	 1.196313 	 0.086627 	 0.140335 	 1.197217
# 0.800000 	 1.375281 	 0.143558 	 0.214379 	 1.377128
# 1.000000 	 1.644836 	 0.220045 	 0.319065 	 1.648721
# 1.200000 	 2.046176 	 0.328967 	 0.473713 	 2.054433
# 1.400000 	 2.646934 	 0.491082 	 0.710432 	 2.664456
# 1.600000 	 3.559596 	 0.741141 	 1.084184 	 3.596640
# 1.800000 	 4.974892 	 1.139071 	 1.691520 	 5.053090
# 2.000000 	 7.223543 	 1.790961 	 2.706341 	 7.389056

# %%
from math import exp

f=lambda x,y:x+y
#z =lambda x:exp((x**2)/2)

x=0
xn=2
y=1
h=0.2
n=int((xn-x)/h)

print("x \t\t y(RK2) \t K1   \t\t K2 ")
print("%f \t %f \t %f \t %f" % (x,y,K1,K2))
    

for i in range(1,n+1):
    K1=h*f(x,y)
    K2=h*f(x+h,y+K1)
    y+=(1/2)*(K1+K2)
    x+=h
    print("%f \t %f \t %f \t %f" % (x,y,K1,K2))
# Out:
# x 		 y(RK2) 	 K1   		 K2
# 0.000000 	 1.000000 	 1.790961 	 2.706341
# 0.200000 	 1.240000 	 0.200000 	 0.280000
# 0.400000 	 1.576800 	 0.288000 	 0.385600
# 0.600000 	 2.031696 	 0.395360 	 0.514432
# 0.800000 	 2.630669 	 0.526339 	 0.671607
# 1.000000 	 3.405416 	 0.686134 	 0.863361
# 1.200000 	 4.394608 	 0.881083 	 1.097300
# 1.400000 	 5.645422 	 1.118922 	 1.382706
# 1.600000 	 7.215414 	 1.409084 	 1.730901
# 1.800000 	 9.174806 	 1.763083 	 2.155699
# 2.000000 	 11.609263 	 2.194961 	 2.673953
